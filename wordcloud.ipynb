# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
stop_w = set(STOPWORDS)
with open("./backup.txt", "r") as file:
    discussion = file.read()
file.close()

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
filtered = [word for word in discussion.split() if not word.lower in stop_words and word.isalpha()]
filtered
# Out:
# ['good',
#  'morning',
#  'good',
#  'afternoon',
#  'and',
#  'if',
#  'listening',
#  'on',
#  'from',
#  'the',
#  'I',
#  'am',
#  'more',
#  'excited',
#  'to',
#  'have',
#  'the',
#  'EC',
#  'here',
#  'to',
#  'my',
#  'knowledge',
#  'I',
#  'think',
#  'this',
#  'is',
#  'the',
#  'first',
#  'time',
#  'the',
#  'EC',
#  'is',
#  'a',
#  'group',
#  'ever',
#  'come',
#  'to',
#  'one',
#  'of',
#  'our',
#  'Tech',
#  'Huds',
#  'so',
#  'it',
#  'should',
#  'be',
#  'a',
#  'really',
#  'good',
#  'affirmation',
#  'of',
#  'the',
#  'importance',
#  'of',
#  'science',
#  'and',
#  'our',
#  'mission',
#  'of',
#  'Healthcare',
#  'of',
#  'why',
#  'we',
#  'have',
#  'such',
#  'a',
#  'and',
#  'as',
#  'we',
#  'looked',
#  'at',
#  'the',
#  'last',
#  'quarter',
#  'and',
#  'I',
#  'did',
#  'the',
#  'town',
#  'hall',
#  'about',
#  'weeks',
#  'ago',
#  'we',
#  'talked',
#  'about',
#  'the',
#  'many',
#  'accomplishments',
#  'seen',
#  'throughout',
# ...

# %%
print(len(filtered))
# import numpy as np
# mask = np.array(Image.open("./johnson-johnson-logo.png"))
filtered2 = WordCloud(stopwords=stop_w, width=1600, height=800, background_color="white", colormap="Set2").generate(discussion)
img = filtered2.to_image()

img.show()
# Out:
# 5941

# %%
import pandas as pd
df = pd.Series(filtered).value_counts().reset_index()
df.columns = ["Words", "Count"]
df.to_csv("Result.csv", index = False)
